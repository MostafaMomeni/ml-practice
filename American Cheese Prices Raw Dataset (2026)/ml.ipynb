# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data/costinflation-american-cheese-retail-prices-raw-2026-07-13-to-2026-08-10.csv")
df.head()
# Out:
#          series_id     series_title  \
# 0  american_cheese  American cheese
# 1  american_cheese  American cheese
# 2  american_cheese  American cheese
# 3  american_cheese  American cheese
# 4  american_cheese  American cheese
#
#                                        canonical_url geography_type  \
# 0  https://costinflation.com/indices/american-che...    postal_code
# 1  https://costinflation.com/indices/american-che...    postal_code
# 2  https://costinflation.com/indices/american-che...    postal_code
# 3  https://costinflation.com/indices/american-che...    postal_code
# 4  https://costinflation.com/indices/american-che...    postal_code
#
#    geography_id                    geography_label observed_date  \
# 0         11385  New York, NY - Ridgewood/Glendale    2026-07-13
# 1         11385  New York, NY - Ridgewood/Glendale    2026-07-13
# 2         11385  New York, NY - Ridgewood/Glendale    2026-07-13
# 3         11385  New York, NY - Ridgewood/Glendale    2026-07-13
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12039 entries, 0 to 12038
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   series_id                  12039 non-null  object
#  1   series_title               12039 non-null  object
#  2   canonical_url              12039 non-null  object
#  3   geography_type             12039 non-null  object
#  4   geography_id               12039 non-null  int64
#  5   geography_label            12039 non-null  object
#  6   observed_date              12039 non-null  object
#  7   product_name               12039 non-null  object
#  8   quantity_value             12039 non-null  float64
#  9   quantity_unit              12039 non-null  object
#  10  quantity_name              12039 non-null  object
#  11  price_amount               12039 non-null  float64
#  12  currency_code              12039 non-null  object
# ...
